# %% [markdown]
# <a href="https://colab.research.google.com/github/loka1282/GoogleColabb/blob/SalesPred/SaledPred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/advertising.csv")
print(data.head())
print(data)
print(data.isnull().sum())

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.scatterplot(x=data['Sales'], y=data['Newspaper'])

plt.show()
sns.scatterplot(x=data['Sales'], y=data['Radio'], color='red')
plt.show()

sns.scatterplot(x=data['Sales'], y=data['TV'], color='green')
plt.show()

correlation = data.corr()
print(correlation['Sales'])

x=np.array(data.drop("Sales",1))
y=np.array(data["Sales"])
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)
model=LinearRegression()
model.fit(xtrain,ytrain)
print(model.score(xtest,ytest))

#features = [[TV, Radio, Newspaper]]

features = np.array([[230.1, 37.8, 69.2]])

print(model.predict(features))
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Sales        1.000000
# Name: Sales, dtype: float64
# 0.9091484341849798
# [21.5057118]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
